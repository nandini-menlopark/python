# %%
import pandas

class Store(object):
    def __init__(self, name, date):
        self.data = {}
        self.id = 0
        self.name = name
        self.dat = date
    
    def getName(self):
        return(self.name)
    
    def getDate(self):
        return(self.date)
